# %% [markdown]
# <a href="https://colab.research.google.com/github/aleugit/MLHW3/blob/master/HW3CreditCard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sklearn as sk
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
import random

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('creditcard160k.csv', low_memory=False)
df = df.sample(frac=1).reset_index(drop=True)

# !ls

df.head(10)

file = pd.read_csv('creditcard160k.csv')
# Out:
# creditcard160k.csv  creditcard.csv  test_transaction.csv
# creditcard3k.csv    sample_data

# %%
fraud = df.loc[df['Class'] == 1]
non_fraud = df.loc[df['Class'] == 0]
print(len(fraud))
print(len(non_fraud))
# Out:
# 73
# 15926

# %%
#visualization with Seabird

fraud = df.loc[df['Class'] == 1]
non_fraud = df.loc[df['Class'] == 0]


ax = sns.scatterplot(x="Amount", y="Class",
                     hue="V1", size="V2",
                     palette=cmap, sizes=(20, 300),
                     data=df)

# %%
ax = fraud.plot.scatter(x='Amount', y='Class', color='Orange', label='Fraud')
non_fraud.plot.scatter(x='Amount', y='Class', color='Blue', label='Normal', ax=ax)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model

x = df.iloc[:,:-1]
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.29)

# %%
logistic = linear_model.LogisticRegression(C=1e5)
logistic.fit(X_train, y_train)
print('Score: ', logistic.score(X_test, y_test))

y_predicted = np.array(logistic.predict(X_test))

plt.plot(y_predicted)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Score:  0.9987068965517242

# %% [markdown]
# I used a CreditCard.csv file with 160k records. THe CreditCard.csv was throwing an python error
# **"Input contains NaN, infinity or a value too large for dtype('float64') even when isnan and isinf are false and dtype=float64"**

# %%
y_predicted = np.array(logistic.predict(X_test))
print(y_predicted)
# Out:
# [0 0 0 ... 0 0 0]
